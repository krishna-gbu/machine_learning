# %%
import pandas as pd

# %%
# 2 main datatypes
series= pd.Series(['bmw','toyota','honda'])

# %%
series
# Out:
# 0       bmw
# 1    toyota
# 2     honda
# dtype: object

# %%
#series = 1-dimensional

# %%
colours=pd.Series(['red','blue','white'])

# %%
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
#dataFrame= 2-dimensional
car_data = pd.DataFrame({'car':series,'color':colours})

# %%
car_data
# Out:
#       car  color
# 0     bmw    red
# 1  toyota   blue
# 2   honda  white

# %%
#import data
heart=pd.read_csv('heart.csv')

# %%
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#exporting data fram
heart.to_csv('exported-car-sales.csv',index=False)

# %%
export_car = pd.read_csv('exported-car-sales.csv')

# %%
export_car
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
   car_sales=pd.read_csv('car_salesM.csv')
   car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra             854.000               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# # describe data

# %%
## attribut //check data type
car_sales.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Latest_Launch', 'Power_perf_factor', 'Seats', 'Fuel_efficiency(L)',
#        'Number of wheels'],
#       dtype='object')

# %%
# check index of file
car_sales.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra             854.000               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# Function
car_sales.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           122.000000          155.000000
# mean            63.926726            21.326475           27.390755
# std            103.138664            37.702759           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.351000            11.268750           18.017500
# 50%             31.148000            14.195000           22.799000
# 75%             71.186000            19.886250           31.947500
# max            854.000000           415.000000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  122 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
car_sales.mean()
# Out:
# Sales_in_thousands      63.926726
# __year_resale_value     21.326475
# Price_in_thousands      27.390755
# Engine_size              3.060897
# Horsepower             185.948718
# Wheelbase              107.487179
# Width                   71.150000
# Length                 187.343590
# Curb_weight              3.378026
# Fuel_capacity           17.951923
# Fuel_efficiency         23.844156
# Power_perf_factor       77.043591
# dtype: float64

# %%
car_prices = pd.Series([200,400,600])

# %%
car_sales.sum()
# Out:
# Manufacturer           AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Model                  IntegraTLCLRLA4A6A8323i328i528iCenturyRegalPar...
# Sales_in_thousands                                               10036.5
# __year_resale_value                                              2601.83
# Vehicle_type           PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                               4245.57
# Engine_size                                                        477.5
# Horsepower                                                         29008
# Wheelbase                                                          16768
# Width                                                            11099.4
# Length                                                           29225.6
# Curb_weight                                                      523.594
# Fuel_capacity                                                     2800.5
# ...

# %%
len(car_sales)
# Out:
# 157

# %%
car_data.color.dtypes
# Out:
# dtype('O')

# %% [markdown]
# # viewing and selection data

# %%
car_sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra             854.000               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
car_sales.tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
# .loc and .iloc
animal =pd.Series(['cat','dog','bird','panda','snake'],index=[0,3,5,7,3])

# %%
animal
# Out:
# 0      cat
# 3      dog
# 5     bird
# 7    panda
# 3    snake
# dtype: object

# %%
animal[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
# .loc // prefer to index
animal.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
#.iloc // prefer to position
animal.iloc[3]
# Out:
# 'panda'

# %%
animal.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 5    bird
# dtype: object

# %%
car_sales['Manufacturer']
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4       Audi
#        ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
#both are same only syntax change
car_sales['Model']  # use for  space in name
car_sales.Model
# Out:
# 0      Integra
# 1           TL
# 2           CL
# 3           RL
# 4           A4
#         ...
# 152        V40
# 153        S70
# 154        V70
# 155        C70
# 156        S80
# Name: Model, Length: 157, dtype: object

# %%
car_sales.Model
# Out:
# 0      Integra
# 1           TL
# 2           CL
# 3           RL
# 4           A4
#         ...
# 152        V40
# 153        S70
# 154        V70
# 155        C70
# 156        S80
# Name: Model, Length: 157, dtype: object

# %%
car_sales[car_sales["Horsepower"] == 'BMW']
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales_in_thousands, __year_resale_value, Vehicle_type, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Width, Length, Curb_weight, Fuel_capacity, Fuel_efficiency, Latest_Launch, Power_perf_factor]
# Index: []

# %%
car_sales[car_sales["Horsepower"] >= 170 ]
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 1          Acura            TL              39.384               19.875
# 2          Acura            CL              14.114               18.225
# 3          Acura            RL               8.588               29.725
# 5           Audi            A6              18.780               23.555
# 6           Audi            A8               1.380               39.000
# ..           ...           ...                 ...                  ...
# 138       Toyota        Avalon              63.849               18.140
# 141       Toyota        Sienna              65.119                  NaN
# 144       Toyota  Land Cruiser               9.835               34.080
# 155        Volvo           C70               3.493                  NaN
# 156        Volvo           S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
#crosstab // for comparing column
pd.crosstab(car_sales['Model'],car_sales['Manufacturer'])
# Out:
# Manufacturer  Acura  Audi  BMW  Buick  Cadillac  Chevrolet  Chrysler  Dodge  \
# Model
# 03-Sep            0     0    0      0         0          0         0      0
# 05-Sep            0     0    0      0         0          0         0      0
# 3000GT            0     0    0      0         0          0         0      0
# 300M              0     0    0      0         0          0         1      0
# 323i              0     0    1      0         0          0         0      0
# ...             ...   ...  ...    ...       ...        ...       ...    ...
# Viper             0     0    0      0         0          0         0      1
# Voyager           0     0    0      0         0          0         0      0
# Windstar          0     0    0      0         0          0         0      0
# Wrangler          0     0    0      0         0          0         0      0
# Xterra            0     0    0      0         0          0         0      0
#
# ...

# %%
# groupby
car_sales.groupby(['Manufacturer']).mean()
# Out:
#               Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# Manufacturer
# Acura                 229.021500            21.046250           30.633333
# Audi                   13.519000            28.270000           39.980000
# BMW                   159.252667           159.933333           33.096667
# Buick                  60.504750            14.941250           26.781250
# Cadillac              111.928400            23.393750           40.254000
# Chevrolet              61.596111            13.230625           20.022778
# Chrysler               28.817286            14.961667           23.430833
# Dodge                  82.740818            16.850500           24.213636
# Ford                  183.875909            12.960000           21.047273
# Honda                 118.534800            15.557000           20.277000
# Hyundai                45.775333             7.531667           12.165667
# ...

# %%
car_sales['Sales_in_thousands'].plot();
# not show plot so use 
# %matplotlib inline
#car_sales['Sales_in_thousands'].plot()

# %%
car_sales['Horsepower'].hist()
# Out:
# <AxesSubplot:>

# %%
# convert object data to int for ploting
carConvert= pd.to_datetime(car_sales['Latest_Launch'])

# %%
carConvert
carConvert.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating Data

# %%
car_sales
car_sales['Manufacturer'].str.lower()
# Out:
# 0      acura
# 1      acura
# 2      acura
# 3      acura
# 4       audi
#        ...
# 152    volvo
# 153    volvo
# 154    volvo
# 155    volvo
# 156    volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
car_sales['Manufacturer'] = car_sales['Manufacturer'].str.lower()
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car_missing=pd.read_csv('Car_sales_Missing.csv')

# %%
car_missing
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra                 NaN               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# fill missing value(NAN)
car_missing['Sales_in_thousands'].fillna(car_missing['Sales_in_thousands'].mean(),inplace=True)

# %%
car_missing
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra           55.977279               16.360
# 1          Acura       TL           39.384000               19.875
# 2          Acura       CL           14.114000               18.225
# 3          Acura       RL            8.588000               29.725
# 4           Audi       A4           20.397000               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40            3.545000                  NaN
# 153        Volvo      S70           15.245000                  NaN
# 154        Volvo      V70           17.531000                  NaN
# 155        Volvo      C70            3.493000                  NaN
# 156        Volvo      S80           18.969000                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#drop NAN value
car_missing.dropna()
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra           55.977279               16.360
# 1          Acura       TL           39.384000               19.875
# 3          Acura       RL            8.588000               29.725
# 4           Audi       A4           20.397000               22.255
# 5           Audi       A6           18.780000               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf            9.761000               11.425
# 146   Volkswagen    Jetta           83.721000               13.240
# 147   Volkswagen   Passat           51.102000               16.725
# 148   Volkswagen   Cabrio            9.569000               16.575
# 149   Volkswagen      GTI            5.596000               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# Column  from series
seats_column = pd.Series([5,5,5,5])
#new Coloumn called seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car_sales['Seats'].fillna(5,inplace=True)

# %%
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car_sales['Fuel_efficiency(L)'] =car_sales['Fuel_efficiency']/2 * 100
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# creating a column from a single value
car_sales['Number of wheels'] = 4
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# drop a column 
car_sales = car_sales.drop("Fuel_efficiency",axis=1)
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra             854.000               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#sample(0=<fraction=<1) // suffle index
car_suffle=car_sales.sample(frac=.2)

# %%
#reset_index(drop=True,inplace=True)
car_suffle.reset_index(drop=True,inplace=True)
car_suffle
# Out:
#    Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 0         dodge        Intrepid              88.028               12.275
# 1      cadillac         Seville              15.943               27.100
# 2        toyota          Avalon              63.849               18.140
# 3    volkswagen          Cabrio               9.569               16.575
# 4    mercedes-b         E-Class              27.602               41.450
# 5        saturn              SW               5.223               10.790
# 6    volkswagen            Golf               9.761               11.425
# 7         acura              RL               8.588               29.725
# 8       mercury     Mountaineer              27.609               20.430
# 9          audi              A8               1.380               39.000
# 10        dodge           Viper               0.916               58.470
# 11        honda           Civic             199.685                9.850
# ...

# %%
car_suffle['Sales_in_thousands']=car_suffle['Sales_in_thousands'].apply(lambda x:x/1.5)
car_suffle
# Out:
#    Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 0         dodge        Intrepid           58.685333               12.275
# 1      cadillac         Seville           10.628667               27.100
# 2        toyota          Avalon           42.566000               18.140
# 3    volkswagen          Cabrio            6.379333               16.575
# 4    mercedes-b         E-Class           18.401333               41.450
# 5        saturn              SW            3.482000               10.790
# 6    volkswagen            Golf            6.507333               11.425
# 7         acura              RL            5.725333               29.725
# 8       mercury     Mountaineer           18.406000               20.430
# 9          audi              A8            0.920000               39.000
# 10        dodge           Viper            0.610667               58.470
# 11        honda           Civic          133.123333                9.850
# ...

# %%
ls
# Out:
#  Volume in drive E is HDD Volume
#  Volume Serial Number is EEC8-F5E5
#
#  Directory of E:\machine learning udemy
#
# 28-01-2022  03:48 PM    <DIR>          .
# 28-01-2022  03:48 PM    <DIR>          ..
# 26-11-2021  10:22 AM    <DIR>          .ipynb_checkpoints
# 22-11-2021  03:08 PM    <DIR>          [FreeCourseSite.com] Udemy - Complete Machine Learning & Data Science Bootcamp 2021
# 02-10-2021  02:05 PM           101,668 6-step.png
# 12-04-2021  09:41 PM            21,333 9.1 scikit-learn-data.zip
# 03-10-2021  01:18 PM            16,089 Car_sales_Missing.csv
# 03-10-2021  01:17 PM            16,102 car_salesM.csv
# 04-10-2021  10:50 PM               369 car-sales.csv
# 01-10-2021  09:28 PM               287 car-sales-missing-data.csv
# 30-09-2021  04:24 PM            41,784 cat.jpg
# 30-09-2021  04:27 PM           530,181 checkface.jpg
# 26-11-2021  10:37 AM    <DIR>          data
# 26-01-2022  11:06 PM    <DIR>          env
# ...

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6],index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64
